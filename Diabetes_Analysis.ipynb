# %% [markdown]
# <a href="https://colab.research.google.com/github/Mariyamkhair/https-colab.research.google.com-drive-1CZWbKJCYQb85JdTyHSM3HCzNkGPs04DX-/blob/main/Diabetes_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
import matplotlib.pyplot as plt
df['Age'].hist()

plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
plt.scatter(df['Glucose'], df['BMI'])

plt.title("Glucose vs BMI")
plt.xlabel("Glucose")
plt.ylabel("BMI")
plt.show()

# %%
df['Outcome'].value_counts().plot(kind='bar')

plt.title("Diabetes Outcome Count")
plt.xlabel("Outcome")
plt.ylabel("Count")
plt.show()

# %%
plt.boxplot(df['Insulin'])

plt.title("Box Plot of Insulin")
plt.ylabel("Insulin")
plt.show()

# %%
plt.plot(df['Glucose'])

plt.title("Glucose Trend")
plt.xlabel("Index")
plt.ylabel("Glucose")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load dataset
df = pd.read_csv("diabetes.csv")

# %%
# Apply seaborn styling
sns.set_style("whitegrid")

# %%
sns.histplot(df['Age'], bins=10)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
plt.title("Age Distribution")
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %%
plt.xlabel("Age")
# Out:
# Text(0.5, 0, 'Age')

# %%
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.show()

# %%
sns.scatterplot(x='Glucose', y='BMI', data=df)
# Out:
# <Axes: xlabel='Glucose', ylabel='BMI'>

# %%
plt.title("Glucose vs BMI")
plt.show()

# %%
sns.countplot(x='Outcome', data=df)

plt.title("Diabetes Outcome Count")
plt.xlabel("Outcome")
plt.ylabel("Count")
plt.show()

# %%
sns.boxplot(y='Insulin', data=df)

plt.title("Box Plot of Insulin")
plt.show()

# %%
sns.lineplot(x=df.index, y='Glucose', data=df)
# Out:
# <Axes: xlabel='None', ylabel='Glucose'>

# %%
plt.title("Glucose Trend")
# Out:
# Text(0.5, 1.0, 'Glucose Trend')

# %%
plt.xlabel("Index")
# Out:
# Text(0.5, 0, 'Index')

# %%
plt.ylabel("Glucose")
# Out:
# Text(0, 0.5, 'Glucose')

# %% [markdown]
# WHY I PREFER THIS: Better Appearance
# Seaborn charts look cleaner and more professional without adding much extra code.
#
# Easier to Read
# The built-in gridlines, spacing, and smoother designs make the charts easier to understand.
#
# Less Customization Needed
# With Matplotlib, you often need extra code to improve styling. Seaborn already applies attractive themes automatically.
#
# Better for Data Analysis Reports
# Seaborn visualizations are commonly used in data science and academic projects because they present data clearly.
#
# Works Well with Pandas DataFrames
# Seaborn integrates directly with Pandas columns, making plotting simpler and faster.

# %%
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("diabetes.csv")

sns.boxplot(x='Outcome', y='Glucose', data=df)

plt.title("Glucose Level by Diabetes Outcome")
plt.xlabel("Outcome")
plt.ylabel("Glucose")
plt.show()

# %%
sns.boxplot(x='Outcome', y='BMI', data=df)

plt.title("BMI by Diabetes Outcome")
plt.xlabel("Outcome")
plt.ylabel("BMI")
plt.show()

# %%
# Create age groups
df['AgeGroup'] = pd.cut(df['Age'],
                        bins=[20,30,40,50,60,70,80],
                        labels=['20-30','31-40','41-50','51-60','61-70','71-80'])

sns.countplot(x='AgeGroup', hue='Outcome', data=df)

plt.title("Diabetes Outcome Across Age Groups")
plt.xlabel("Age Group")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# I would further investigate how blood pressure and insulin levels relate to diabetes outcome. It would also be useful to study whether pregnancy history increases diabetes risk among different age groups.
#
# In future analysis, I would combine this dataset with lifestyle datasets containing information about diet, exercise, smoking, and sleep patterns. Additional features such as family medical history, daily sugar intake, and physical activity levels would help improve the analysis and prediction of diabetes risk.
